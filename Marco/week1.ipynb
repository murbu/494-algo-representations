# %%
import pandas as pd

# %%
df = pd.read_csv("../notes-00000.tsv", sep="\t")
# Out:
# /var/folders/vs/cp4_j_996rz55hth8zrbfrgw0000gn/T/ipykernel_3526/1137875644.py:1: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../notes-00000.tsv", sep="\t")

# %%
df.shape
# Out:
# (2347611, 24)
